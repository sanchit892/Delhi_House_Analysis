# %%
# import major libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Import dataset from local system

df = pd.read_csv('MagicBricks.csv')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# 1                                 Dev Nagar, Karol Bagh      1.0
# 2                                            Karol Bagh      2.0
# 3                             The Amaryllis, Karol Bagh      2.0
# 4                             The Amaryllis, Karol Bagh      2.0
# ...                                                 ...      ...
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
# 1212                                        Uttam Nagar      1.0
# 1213                                        Uttam Nagar      1.0
#
#              Status   Transaction           Type  Per_Sqft      Price
# 0     Ready_to_move        Resale      Apartment    8761.0   12500000
# 1     Ready_to_move  New_Property      Apartment    7290.0    3900000
# 2     Ready_to_move        Resale  Builder_Floor   14092.0   15000000
# 3      Almost_ready        Resale      Apartment   22222.0   25000000
# 4      Almost_ready        Resale      Apartment   22222.0   25000000
# ...             ...           ...            ...       ...        ...
# 1209   Almost_ready  New_Property      Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property      Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property      Apartment   24718.0   57000000
# 1212  Ready_to_move        Resale  Builder_Floor    5794.0    2900000
# 1213  Ready_to_move        Resale  Builder_Floor    5794.0    3200000
#
# [1214 rows x 13 columns]

# %%
# Data Disription and Data Information 

df.describe() # It will only work with Numeric Values or Continious Values
# Out:
#                Area          BHK     Bathroom      Parking       Per_Sqft  \
# count   1214.000000  1214.000000  1212.000000  1182.000000     973.000000
# mean    1451.850751     2.778418     2.523927     1.708122   15574.885920
# std     1586.472855     0.946811     1.017723     5.717177   21574.389007
# min       28.000000     1.000000     1.000000     1.000000    1259.000000
# 25%      800.000000     2.000000     2.000000     1.000000    6154.000000
# 50%     1150.000000     3.000000     2.000000     1.000000   10838.000000
# 75%     1620.000000     3.000000     3.000000     2.000000   17647.000000
# max    24300.000000    10.000000     7.000000   114.000000  183333.000000
#
#               Price
# count  1.214000e+03
# mean   2.079898e+07
# std    2.561308e+07
# min    1.000000e+06
# 25%    5.600000e+06
# 50%    1.400000e+07
# 75%    2.500000e+07
# max    2.400000e+08

# %%
# Information regarding to the Dataset.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1214 entries, 0 to 1213
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Area         1214 non-null   float64
#  1   BHK          1214 non-null   int64
#  2   Bathroom     1212 non-null   float64
#  3   Furnishing   1214 non-null   object
#  4   Location     1214 non-null   object
#  5   District     1214 non-null   object
#  6   Locality     1214 non-null   object
#  7   Parking      1182 non-null   float64
#  8   Status       1214 non-null   object
#  9   Transaction  1214 non-null   object
#  10  Type         1209 non-null   object
#  11  Per_Sqft     973 non-null    float64
#  12  Price        1214 non-null   int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 123.4+ KB

# %%
# Checking Missing Values in a Dataset.

df.isnull().sum()
# Out:
# Area             0
# BHK              0
# Bathroom         2
# Furnishing       0
# Location         0
# District         0
# Locality         0
# Parking         32
# Status           0
# Transaction      0
# Type             5
# Per_Sqft       241
# Price            0
# dtype: int64

# %%
# Filling Null Values with appropriate data.

df.Bathroom = df.Bathroom.fillna(df.Bathroom.median())
df.Parking = df.Parking.fillna(df.Parking.median())
df.Type = df.Type.fillna('Unknown')
df.Per_Sqft = df.Per_Sqft.fillna(df.Per_Sqft.median())

# %%
# Checking Null Values Again 

df.isnull().sum()
# Out:
# Area           0
# BHK            0
# Bathroom       0
# Furnishing     0
# Location       0
# District       0
# Locality       0
# Parking        0
# Status         0
# Transaction    0
# Type           0
# Per_Sqft       0
# Price          0
# dtype: int64

# %%
# Saving a clean file in local system.

df.to_csv('magic_bricks_cleandata.csv')

# %%
# Using Countplot with District Column

sns.countplot(df.District.sort_values())
# Out:
# <Axes: xlabel='count', ylabel='District'>

# %%
# Pie Chart with Distric to see the % of Data.

plt.pie(df.District.value_counts(),labels=df.District.value_counts().index,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1e133df0ee0>,
#   <matplotlib.patches.Wedge at 0x1e133df0e20>,
#   <matplotlib.patches.Wedge at 0x1e133dfaa30>,
#   <matplotlib.patches.Wedge at 0x1e133e05100>,
#   <matplotlib.patches.Wedge at 0x1e133e057c0>,
#   <matplotlib.patches.Wedge at 0x1e133e05e50>,
#   <matplotlib.patches.Wedge at 0x1e133e12520>,
#   <matplotlib.patches.Wedge at 0x1e133e12bb0>,
#   <matplotlib.patches.Wedge at 0x1e133e1c280>],
#  [Text(0.411070020131639, 1.0203045812643272, 'South Delhi'),
#   Text(-1.0224184282933728, 0.40578388026893014, 'West Delhi'),
#   Text(-1.0296009597182176, -0.3871974480124132, 'East Delhi'),
#   Text(-0.5712251398707956, -0.9400541684283892, 'North West Delhi'),
#   Text(0.017078746572777605, -1.0998674085613698, 'South West Delhi'),
#   Text(0.5142950307378011, -0.9723685625103294, 'South West Delhi '),
#   Text(0.8655640918347755, -0.6788216282104164, 'Shahdara'),
#   Text(1.0447457644052096, -0.3442474222959039, 'South East Delhi'),
#   Text(1.0962305570630642, -0.09098662407851114, 'Central Delhi')],
#  [Text(0.22422001098089397, 0.5565297715987239, '37.8%'),
#   Text(-0.5576827790691125, 0.22133666196487095, '12.4%'),
#   Text(-0.5616005234826641, -0.2111986080067708, '11.1%'),
#   Text(-0.31157734902043394, -0.5127568191427576, '10.0%'),
#   Text(0.009315679948787785, -0.5999276773971107, '7.8%'),
#   Text(0.2805245622206188, -0.5303828522783615, '7.2%'),
#   Text(0.47212586827351377, -0.37026634266022707, '6.2%'),
#   Text(0.5698613260392053, -0.1877713212523112, '4.9%'),
#   Text(0.5979439402162167, -0.04962906767918789, '2.6%')])

# %%
df.District.value_counts()
# Out:
# District
# South Delhi          459
# West Delhi           150
# East Delhi           135
# North West Delhi     122
# South West Delhi      95
# South West Delhi      87
# Shahdara              75
# South East Delhi      59
# Central Delhi         32
# Name: count, dtype: int64

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# 1                                 Dev Nagar, Karol Bagh      1.0
# 2                                            Karol Bagh      2.0
# 3                             The Amaryllis, Karol Bagh      2.0
# 4                             The Amaryllis, Karol Bagh      2.0
# ...                                                 ...      ...
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
# 1212                                        Uttam Nagar      1.0
# 1213                                        Uttam Nagar      1.0
#
#              Status   Transaction           Type  Per_Sqft      Price
# 0     Ready_to_move        Resale      Apartment    8761.0   12500000
# 1     Ready_to_move  New_Property      Apartment    7290.0    3900000
# 2     Ready_to_move        Resale  Builder_Floor   14092.0   15000000
# 3      Almost_ready        Resale      Apartment   22222.0   25000000
# 4      Almost_ready        Resale      Apartment   22222.0   25000000
# ...             ...           ...            ...       ...        ...
# 1209   Almost_ready  New_Property      Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property      Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property      Apartment   24718.0   57000000
# 1212  Ready_to_move        Resale  Builder_Floor    5794.0    2900000
# 1213  Ready_to_move        Resale  Builder_Floor    5794.0    3200000
#
# [1214 rows x 13 columns]

# %%
# Compare Prices of Karol Bagh and Patel Nagar homes.

df[df.Location=='Karol Bagh'].Price
# Out:
# 0      12500000
# 1       3900000
# 2      15000000
# 3      25000000
# 4      25000000
# 5      25000000
# 6      24500000
# 176     6540000
# 177     6800000
# 178     7000000
# 179    10000000
# 180    20000000
# 181     5500000
# 182    14500000
# 183    24000000
# 184    25500000
# 185    18500000
# 186    39700000
# 187    22000000
# 188    25500000
# 189    17000000
# 190    27500000
# 191    25500000
# 192    20000000
# 193    20900000
# 194    43100000
# 853    16000000
# 854    16000000
# 855     4100000
# 856     5000000
# 857    73700000
# 858    52300000
# Name: Price, dtype: int64

# %%
df[df.Location=='Patel Nagar']
# Out:
#         Area  BHK  Bathroom      Furnishing     Location    District  \
# 165   1800.0    3       3.0       Furnished  Patel Nagar  West Delhi
# 166     70.0    2       3.0       Furnished  Patel Nagar  West Delhi
# 167    900.0    2       2.0       Furnished  Patel Nagar  West Delhi
# 168    900.0    3       2.0       Furnished  Patel Nagar  West Delhi
# 808   2000.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 809   1530.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 810    100.0    3       2.0  Semi-Furnished  Patel Nagar  West Delhi
# 811   1800.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 812    200.0    1       1.0  Semi-Furnished  Patel Nagar  West Delhi
# 813   1782.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 814    900.0    3       2.0  Semi-Furnished  Patel Nagar  West Delhi
# 815   1680.0    4       5.0  Semi-Furnished  Patel Nagar  West Delhi
# 816   2000.0    4       4.0  Semi-Furnished  Patel Nagar  West Delhi
# 817    950.0    2       2.0  Semi-Furnished  Patel Nagar  West Delhi
# 818   1500.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 819    850.0    2       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 820    405.0    2       1.0  Semi-Furnished  Patel Nagar  West Delhi
# 839   1900.0    3       3.0  Semi-Furnished  Patel Nagar  West Delhi
# 1187   800.0    3       2.0     Unfurnished  Patel Nagar  West Delhi
# 1188   270.0    1       1.0     Unfurnished  Patel Nagar  West Delhi
# 1189  1800.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
# 1190   900.0    3       2.0     Unfurnished  Patel Nagar  West Delhi
# 1191  1800.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
# 1192  1500.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
# 1201   140.0    3       2.0     Unfurnished  Patel Nagar  West Delhi
# 1203  4688.0    5       4.0     Unfurnished  Patel Nagar  West Delhi
# 1204  3901.0    4       4.0     Unfurnished  Patel Nagar  West Delhi
# 1205  2306.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
# 1206  4688.0    5       4.0     Unfurnished  Patel Nagar  West Delhi
# 1207  3901.0    4       4.0     Unfurnished  Patel Nagar  West Delhi
# 1208  2306.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
# 1209  4688.0    5       4.0     Unfurnished  Patel Nagar  West Delhi
# 1210  3901.0    4       4.0     Unfurnished  Patel Nagar  West Delhi
# 1211  2306.0    3       3.0     Unfurnished  Patel Nagar  West Delhi
#
#                                Locality  Parking         Status   Transaction  \
# 165       Patel Nagar East, Patel Nagar      3.0  Ready_to_move        Resale
# 166      Patel Nagar South, Patel Nagar      1.0  Ready_to_move  New_Property
# 167                    Patel Nagar West      3.0  Ready_to_move        Resale
# 168                    Patel Nagar West      2.0  Ready_to_move        Resale
# 808       Patel Nagar East, Patel Nagar      1.0  Ready_to_move        Resale
# 809       Patel Nagar East, Patel Nagar      2.0  Ready_to_move        Resale
# 810       Patel Nagar East, Patel Nagar      2.0  Ready_to_move        Resale
# 811       Patel Nagar East, Patel Nagar      2.0  Ready_to_move        Resale
# 812       Patel Nagar East, Patel Nagar      1.0  Ready_to_move        Resale
# 813       Patel Nagar East, Patel Nagar      1.0  Ready_to_move        Resale
# 814                    Patel Nagar West      1.0  Ready_to_move        Resale
# 815                    Patel Nagar West      1.0  Ready_to_move        Resale
# 816                    Patel Nagar West      3.0  Ready_to_move        Resale
# 817                    Patel Nagar West      2.0  Ready_to_move        Resale
# 818                    Patel Nagar West      2.0  Ready_to_move        Resale
# 819                    Patel Nagar West      1.0  Ready_to_move        Resale
# 820                    Patel Nagar West      1.0  Ready_to_move        Resale
# 839   The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1187                   Patel Nagar West      1.0  Ready_to_move        Resale
# 1188                   Patel Nagar West      2.0  Ready_to_move        Resale
# 1189                   Patel Nagar West      3.0  Ready_to_move        Resale
# 1190                   Patel Nagar West      1.0  Ready_to_move        Resale
# 1191                   Patel Nagar West      1.0  Ready_to_move        Resale
# 1192                   Patel Nagar West      1.0  Ready_to_move        Resale
# 1201         Punjabi Basti, Patel Nagar      1.0  Ready_to_move  New_Property
# 1203  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1204  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1205  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1206  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1207  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1208  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1209  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1210  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
# 1211  The Leela Sky Villas, Patel Nagar      1.0   Almost_ready  New_Property
#
#                Type  Per_Sqft      Price
# 165       Apartment   27778.0   50000000
# 166   Builder_Floor   23840.0    8200000
# 167   Builder_Floor   23840.0    7400000
# 168   Builder_Floor   11556.0   10400000
# 808       Apartment   23840.0   37500000
# 809   Builder_Floor    7500.0   26500000
# 810       Apartment  160000.0   16000000
# 811   Builder_Floor    8421.0   27000000
# 812       Apartment   13333.0    7000000
# 813       Apartment    8418.0   15000000
# 814   Builder_Floor   23840.0    9500000
# 815   Builder_Floor   23840.0   20000000
# 816   Builder_Floor    7500.0   15000000
# 817   Builder_Floor    8421.0    8000000
# 818   Builder_Floor    8421.0   19500000
# 819   Builder_Floor   24718.0    5900000
# 820       Apartment    1667.0    3950000
# 839       Apartment    7500.0   55300000
# 1187  Builder_Floor   23840.0    8000000
# 1188  Builder_Floor   11556.0    1700000
# 1189  Builder_Floor   11722.0   21100000
# 1190  Builder_Floor   13333.0   12000000
# 1191      Apartment   13333.0   24000000
# 1192  Builder_Floor    8333.0   12500000
# 1201  Builder_Floor   85714.0   12000000
# 1203      Apartment   28797.0  135000000
# 1204      Apartment   23840.0   93000000
# 1205      Apartment   24718.0   57000000
# 1206      Apartment   28797.0  135000000
# 1207      Apartment   23840.0   93000000
# 1208      Apartment   24718.0   57000000
# 1209      Apartment   28797.0  135000000
# 1210      Apartment   23840.0   93000000
# 1211      Apartment   24718.0   57000000

# %%
plt.scatter(x = df[df.Location=='Karol Bagh'].Price.head(10),y = df[df.Location=='Karol Bagh'].Area.head(10),
           color='b',marker='*')

plt.scatter(x = df[df.Location=='Patel Nagar'].Price.head(10),y = df[df.Location=='Karol Bagh'].Area.head(10),
           color='g',marker='o')

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# 1                                 Dev Nagar, Karol Bagh      1.0
# 2                                            Karol Bagh      2.0
# 3                             The Amaryllis, Karol Bagh      2.0
# 4                             The Amaryllis, Karol Bagh      2.0
# ...                                                 ...      ...
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
# 1212                                        Uttam Nagar      1.0
# 1213                                        Uttam Nagar      1.0
#
#              Status   Transaction           Type  Per_Sqft      Price
# 0     Ready_to_move        Resale      Apartment    8761.0   12500000
# 1     Ready_to_move  New_Property      Apartment    7290.0    3900000
# 2     Ready_to_move        Resale  Builder_Floor   14092.0   15000000
# 3      Almost_ready        Resale      Apartment   22222.0   25000000
# 4      Almost_ready        Resale      Apartment   22222.0   25000000
# ...             ...           ...            ...       ...        ...
# 1209   Almost_ready  New_Property      Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property      Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property      Apartment   24718.0   57000000
# 1212  Ready_to_move        Resale  Builder_Floor    5794.0    2900000
# 1213  Ready_to_move        Resale  Builder_Floor    5794.0    3200000
#
# [1214 rows x 13 columns]

# %%
df.groupby('District')['Price'].sum()
# Out:
# District
# Central Delhi          677540000
# East Delhi            1511130000
# North West Delhi       795550000
# Shahdara               827720000
# South Delhi          13717840000
# South East Delhi       813500000
# South West Delhi      2226100000
# South West Delhi      1100370000
# West Delhi            3580210000
# Name: Price, dtype: int64

# %%
plt.barh(df.groupby('District')['Price'].sum().index,df.groupby('District')['Price'].sum())
# Out:
# <BarContainer object of 9 artists>

# %%
df[df.Location=='Karol Bagh'].Price.mean()
# Out:
# 21173125.0

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# 1                                 Dev Nagar, Karol Bagh      1.0
# 2                                            Karol Bagh      2.0
# 3                             The Amaryllis, Karol Bagh      2.0
# 4                             The Amaryllis, Karol Bagh      2.0
# ...                                                 ...      ...
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
# 1212                                        Uttam Nagar      1.0
# 1213                                        Uttam Nagar      1.0
#
#              Status   Transaction           Type  Per_Sqft      Price
# 0     Ready_to_move        Resale      Apartment    8761.0   12500000
# 1     Ready_to_move  New_Property      Apartment    7290.0    3900000
# 2     Ready_to_move        Resale  Builder_Floor   14092.0   15000000
# 3      Almost_ready        Resale      Apartment   22222.0   25000000
# 4      Almost_ready        Resale      Apartment   22222.0   25000000
# ...             ...           ...            ...       ...        ...
# 1209   Almost_ready  New_Property      Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property      Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property      Apartment   24718.0   57000000
# 1212  Ready_to_move        Resale  Builder_Floor    5794.0    2900000
# 1213  Ready_to_move        Resale  Builder_Floor    5794.0    3200000
#
# [1214 rows x 13 columns]

# %%
df[(df.Location=='Karol Bagh') & (df.Parking==3)].Price.mean()
# Out:
# 73700000.0

# %%
plt.title('Heatmap')
sns.heatmap(df[['Area','BHK','Bathroom','Parking','Per_Sqft','Price']].corr(),annot=True)
# Out:
# <Axes: title={'center': 'Heatmap'}>

# %%
df[(df.District=='West Delhi') & (df.Bathroom==5)].Price.mean()
# Out:
# 50050000.0

# %%
df
# Out:
#         Area  BHK  Bathroom   Furnishing     Location       District  \
# 0      950.0    2       2.0    Furnished   Karol Bagh  Central Delhi
# 1      535.0    2       1.0    Furnished   Karol Bagh  Central Delhi
# 2     1280.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 3     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# 4     1135.0    3       3.0    Furnished   Karol Bagh  Central Delhi
# ...      ...  ...       ...          ...          ...            ...
# 1209  4688.0    5       4.0  Unfurnished  Patel Nagar     West Delhi
# 1210  3901.0    4       4.0  Unfurnished  Patel Nagar     West Delhi
# 1211  2306.0    3       3.0  Unfurnished  Patel Nagar     West Delhi
# 1212   675.0    2       1.0  Unfurnished  Uttam Nagar     West Delhi
# 1213   585.0    2       2.0  Unfurnished  Uttam Nagar     West Delhi
#
#                                                Locality  Parking  \
# 0     DDA MIG Flats Prasad Nagar Phase 2, Prasad Nag...      1.0
# 1                                 Dev Nagar, Karol Bagh      1.0
# 2                                            Karol Bagh      2.0
# 3                             The Amaryllis, Karol Bagh      2.0
# 4                             The Amaryllis, Karol Bagh      2.0
# ...                                                 ...      ...
# 1209                  The Leela Sky Villas, Patel Nagar      1.0
# 1210                  The Leela Sky Villas, Patel Nagar      1.0
# 1211                  The Leela Sky Villas, Patel Nagar      1.0
# 1212                                        Uttam Nagar      1.0
# 1213                                        Uttam Nagar      1.0
#
#              Status   Transaction           Type  Per_Sqft      Price
# 0     Ready_to_move        Resale      Apartment    8761.0   12500000
# 1     Ready_to_move  New_Property      Apartment    7290.0    3900000
# 2     Ready_to_move        Resale  Builder_Floor   14092.0   15000000
# 3      Almost_ready        Resale      Apartment   22222.0   25000000
# 4      Almost_ready        Resale      Apartment   22222.0   25000000
# ...             ...           ...            ...       ...        ...
# 1209   Almost_ready  New_Property      Apartment   28797.0  135000000
# 1210   Almost_ready  New_Property      Apartment   23840.0   93000000
# 1211   Almost_ready  New_Property      Apartment   24718.0   57000000
# 1212  Ready_to_move        Resale  Builder_Floor    5794.0    2900000
# 1213  Ready_to_move        Resale  Builder_Floor    5794.0    3200000
#
# [1214 rows x 13 columns]

# %%
print(df[df.Furnishing=='Unfurnished'].Price.mean())
print(df[df.Furnishing=='Furnished'].Price.mean())
print(df[df.Furnishing=='Semi-Furnished'].Price.mean())
# Out:
# 20309556.7867036
# 17171363.636363637
# 22003028.064992614

# %%
df.Furnishing.value_counts()
# Out:
# Furnishing
# Semi-Furnished    677
# Unfurnished       361
# Furnished         176
# Name: count, dtype: int64
